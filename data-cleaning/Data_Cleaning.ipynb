# %%
import json

# %%
#Function to load the data.
def load_data(filename):
    with open(filename, "r") as f:
        data  = json.load(f)
    return data

# %%
data = load_data("data.json")

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
# Function to display users and their connections.
def display_users(data):
    print("Users and there Connections:-\n")
    for user in data['users']:
        print(f"{user['id']}. {user['name']} is friends with: {user['friends']} and liked pages are {user['liked_pages']}")
        
    print("\nPages Information")
    for page in data['pages']:
        print(f"{page['id']} : {page['name']}")

# %%
display_users(data)
# Out:
# Users and there Connections:-
#
# 1. Amit is friends with: [2, 3] and liked pages are [101]
# 2. Priya is friends with: [1, 4] and liked pages are [102]
# 3. Rahul is friends with: [1] and liked pages are [101, 103]
# 4. Sara is friends with: [2] and liked pages are [104]
#
# Pages Information
# 101 : Python Developers
# 102 : Data Science Enthusiasts
# 103 : AI & ML Community
# 104 : Web Dev Hub

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
# Now we get new updated data as data2

# %%
# load the data
#1- data = load_data("data2.json")
#2-
data = json.load(open("data2.json"))

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': '', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Rahul', 'friends': [2, 2], 'liked_pages': [104]},
#   {'id': 5, 'name': 'Sara', 'friends': [], 'liked_pages': []}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'},
#   {'id': 104, 'name': 'Web Dev'}]}

# %%
import json

#Data clean
def clean_data(data):
    # Remove users with a missing name 
    data['users'] = [user for user in data['users'] if user['name'].strip()]
    
    # Remove duplicate friends
    for user in data['users']:
        user['friends'] = list(set(user['friends']))

    # Remove Inactive users
    data['users'] = [user for user in data['users'] if user['friends'] or user['liked_pages']]

    # Remove duplicate pages
    uniqe_pages = {}
    for page in data['pages']:
        uniqe_pages[page['id']] = page
    data['pages'] = list(uniqe_pages.values())
        
    return data

data = clean_data(data)
json.dump(data, open("cleaned_data2.json", "w"), indent=4)
print("Data has been cleaned successfully")
# Out:
# Data has been cleaned successfully

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 4, 'name': 'Rahul', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev'}]}
